# %% [markdown]
# # frames

# %%
import tkinter as tk
from tkinter import *  
import tkinter.font as font

fp =Tk()

fontsize = font.Font(size=40)

p = PanedWindow(fp, orient=HORIZONTAL)

F1 = Frame(fp, bg='gold', bd=5,relief = RAISED)
F2 = LabelFrame(fp, labelanchor = N)# ou : F2 = LabelFrame(fp, text = '', labelanchor = N)
B1 = Button(F1,text='Machine Learning : Liste des Algorithmes')
B1.pack(padx = 10, pady = 10)
F1.pack(padx =10, pady = 10)

B1['font']=fontsize


# Left listbox
left_list = tk.Listbox(fp)
left_list.pack(side=tk.LEFT)
p.add(left_list)

# Right listbox
right_list = tk.Listbox(fp)
right_list.pack(side=tk.LEFT)
p.add(right_list)
# place the panedwindow on the root window
p.pack(fill=tk.BOTH, expand=True)


B2 = Button(F2,text='Quitter',command = fp.destroy)
B2.pack()




B2.pack(padx = 10, pady = 10)

F2.pack(padx =10, pady = 10) 
fp.title('Machine Learning') # Ajout d'un titre
fp.resizable(True, True) # autoriser le redimensionnement vertical et horizontal
fp.geometry("1072x800+80+50")#dimensionner et positionner la fnêtre





p.pack()
fp.mainloop()

# %%
from tkinter import Tk, PanedWindow, Label
root = Tk()
root.title('Hello')
paned = PanedWindow(root, handlesize=4, showhandle=True, sashrelief='sunken')
l1 = Label(paned, text='gauche', height=100, background="white")
l2 = Label(paned, text='droite', height=100, background="white")
paned.add(l1, height=100, sticky="ew")
paned.add(l2, height=100, sticky="ew")
paned.grid(sticky="ew", row=1, column=1)
root.grid_columnconfigure(1, weight=1)
root.mainloop()

# %%
import tkinter as tk
from tkinter import *
import tkinter.font as font

fp =Tk()

fz1 = font.Font(size=40,family='Times New Roman')
fz2 = font.Font(size=15,family='Times New Roman')

p = PanedWindow(fp, orient=HORIZONTAL)

F1 = Frame(fp, bg='gold', bd=5,relief = RAISED)

B1 = Button(F1,text='Machine Learning : Liste des Algorithmes')
B1.pack(padx = 10, pady = 10)
F1.pack(padx =10, pady = 10)

B1['font']=fz1


Frame3 = Frame(fp,borderwidth=4,relief=GROOVE)
Label(Frame3,text="RDV dentiste à 10h",bg="white").pack(padx=100,pady=250)
#Button(Frame3,text="Effacer",fg='navy',command=Frame3.destroy)
Frame3.pack(side=LEFT)

Frame3.pack(fill=tk.BOTH, expand=True)


Frame4 = Frame(fp,borderwidth=4,relief=GROOVE)
Label(Frame4,text="RDV dentiste à minuit",bg="white").pack(padx=250,pady=250)
#Button(Frame3,text="Effacer",fg='navy',command=Frame3.destroy)
Frame4.pack(side=RIGHT)

Frame4.pack(fill=tk.BOTH, expand=True)

#F2 = LabelFrame(fp, labelanchor = N)# ou : F2 = LabelFrame(fp, text = '', labelanchor = N)
B2=Button(fp,text='Quitter',width=9,height=2,bg='red', fg='white',command = fp.destroy)
B2['font']=fz2

B2.pack(side = BOTTOM)



#F2.pack(padx =10, pady = 10) 
B2.pack(padx = 10, pady = 10)
fp.title('Machine Learning') # Ajout d'un titre
fp.resizable(True, True) # autoriser le redimensionnement vertical et horizontal
fp.geometry("1072x800+80+50")#dimensionner et positionner la fnêtre





p.pack()
fp.mainloop()

# %%
import tkinter as tk
from tkinter import ttk  
import tkinter.font as font

fp =Tk()


fz1 = font.Font(size=40,family='Times New Roman',weight="bold")
fz2 = font.Font(size=15,family='Times New Roman',weight="bold")

p = PanedWindow(fp, orient=HORIZONTAL)

F1 = Frame(fp, bg='gold', bd=5,relief = RAISED)
Label(F1,text='Machine Learning : Liste des Algorithmes',font=("Courier", 20,"bold")).pack(padx = 10, pady = 10)
F1.pack(padx =10, pady = 10)




Frame3 = Frame(fp,borderwidth=1,relief=GROOVE)
Label(Frame3,text="RDV dentiste à 10h",bg="white").pack(padx=80,pady=250)
#Button(Frame3,text="Effacer",fg='navy',command=Frame3.destroy)
Frame3.pack(side=LEFT)



Frame3.pack(fill=tk.BOTH, expand=True)


Frame4 = Frame(fp,borderwidth=1,relief=GROOVE)
Label(Frame4,text="RDV dentiste à minuit",bg="white").pack(padx=250,pady=250)
#Button(Frame3,text="Effacer",fg='navy',command=Frame3.destroy)
Frame4.pack(side=RIGHT)

Frame4.pack(fill=tk.BOTH, expand=True)


fp.title('Machine Learning') # Ajout d'un titre
fp.resizable(True, True) # autoriser le redimensionnement vertical et horizontal
fp.geometry("1072x800+80+50")#dimensionner et positionner la fnêtre






p.pack()
fp.mainloop()

# %%
import tkinter as tk
from tkinter import ttk  
import tkinter.font as font

fp =Tk()


fz1 = font.Font(size=40,family='Times New Roman',weight="bold")
fz2 = font.Font(size=15,family='Times New Roman',weight="bold")

p = PanedWindow(fp, orient=HORIZONTAL)

F1 = Frame(fp, bg='gold', bd=5,relief = RAISED)
Label(F1,text='Machine Learning : Liste des Algorithmes',font=("Courier", 20,"bold")).pack(padx = 10, pady = 10)
F1.pack(padx =10, pady = 10)




Frame3 = Frame(fp,borderwidth=1,relief=GROOVE)
Label(Frame3,text="RDV dentiste à 10h",bg="white").pack(padx=80,pady=250)
#Button(Frame3,text="Effacer",fg='navy',command=Frame3.destroy)
Frame3.pack(side=LEFT)



Frame3.pack(fill=tk.BOTH, expand=True)


Frame4 = Frame(fp,borderwidth=1,relief=GROOVE)
Label(Frame4,text="RDV dentiste à minuit",bg="white").pack(padx=250,pady=250)
#Button(Frame3,text="Effacer",fg='navy',command=Frame3.destroy)
Frame4.pack(side=RIGHT)

Frame4.pack(fill=tk.BOTH, expand=True)


fp.title('Machine Learning') # Ajout d'un titre
fp.resizable(True, True) # autoriser le redimensionnement vertical et horizontal
fp.geometry("1072x800+80+50")#dimensionner et positionner la fnêtre

menubar = Menu(fp)
fp.config(menu=menubar) 
menufichier = Menu(menubar,tearoff=0)
menubar.add_cascade(label="Fichier", menu=menufichier)
def ouvrir():
    print ("Bonjour") 

menufichier.add_command(label="Ouvrir ")
menufichier.add_separator()
menufichier.add_command(label="Enregistrer")
menufichier.add_separator()
menufichier.add_command(label="Enregistrer sous")
menufichier.add_separator()
menufichier.add_command(label="Quitter", command=fp.destroy) 






p.pack()
fp.mainloop()

# %%
import tkinter.filedialog
import tkinter as tk
from tkinter import * 
import tkinter.font as font

fp =Tk()


fz1 = font.Font(size=40,family='Times New Roman',weight="bold")
fz2 = font.Font(size=15,family='Times New Roman',weight="bold")

p = PanedWindow(fp, orient=HORIZONTAL)

F1 = Frame(fp, bg='gold', bd=5,relief = RAISED)
Label(F1,text='Machine Learning : Liste des Algorithmes',font=("Courier", 20,"bold")).pack(padx = 10, pady = 10)
F1.pack(padx =10, pady = 10)




Frame3 = Frame(fp,borderwidth=1,relief=GROOVE)
Label(Frame3,text="RDV dentiste à 10h",bg="white").pack(padx=80,pady=250)
#Button(Frame3,text="Effacer",fg='navy',command=Frame3.destroy)
Frame3.pack(side=LEFT)



Frame3.pack(fill=tk.BOTH, expand=True)


Frame4 = Frame(fp,borderwidth=1,relief=GROOVE)
Label(Frame4,text="RDV dentiste à minuit",bg="white").pack(padx=250,pady=250)
#Button(Frame3,text="Effacer",fg='navy',command=Frame3.destroy)
Frame4.pack(side=RIGHT)

Frame4.pack(fill=tk.BOTH, expand=True)


fp.title('Machine Learning') # Ajout d'un titre
fp.resizable(True, True) # autoriser le redimensionnement vertical et horizontal
fp.geometry("1072x800+80+50")#dimensionner et positionner la fnêtre

menubar = Menu(fp)
fp.config(menu=menubar) 
menufile = Menu(menubar,tearoff=0)
menubar.add_cascade(label="File", menu=menufile)
def ouvrir():
    print ("Bonjour") 

menufile.add_command(label="Open ")
menufile.add_separator()

menufile.add_command(label="Save")
menufile.add_separator()

menufile.add_command(label="Save as")
menufile.add_separator()


menufile.add_command(label="Quit", command=fp.destroy) 
menufile.add_separator()

menuedition = Menu(menubar,tearoff=0)
menubar.add_cascade(label="Edit", menu=menuedition)
def alert():
    showinfo("alerte", "Thank You!")


menuedition.add_command(label="Cut")
menuedition.add_separator()

menuedition.add_command(label="Copy")
menuedition.add_separator()

menuedition.add_command(label="Past")
menuedition.add_separator()

menuedition.add_cascade(label="Edit")
menuedition.add_separator()

menuhelp = Menu(menubar, tearoff=0)
menuhelp.add_command(label="About !", command=alert)
menubar.add_cascade(label="Help", menu=menuhelp)



p.pack()
fp.mainloop()
# Out:
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "C:\Users\MSI\anaconda3\lib\tkinter\__init__.py", line 1883, in __call__
#     return self.func(*args)
#   File "<ipython-input-9-09c072568adc>", line 66, in alert
#     showinfo("alerte", "Thank You!")
# NameError: name 'showinfo' is not defined

# %%
import tkinter.filedialog
import tkinter as tk
from tkinter import * 
import tkinter.font as font
from tkinter.filedialog import askopenfilename

def onOpen():
    #print(filedialog.askopenfilename(initialdir = "/",title = "Open file",filetypes = (("Python files","*.py;*.pyw"),("All files","*.*")))) 
    name = askopenfilename(initialdir="/",
                           filetypes =(("pdf File", "*.pdf"),("All Files","*.*")),
                           title = "Choose a file."
                           )
    print (name)
    #Using try in case user types in unknown file or closes without choosing a file.
    try:
        with open(name,'r') as UseFile:
            print(UseFile.read())
    except:
        print("No file exists")



fp =Tk()


fz1 = font.Font(size=40,family='Times New Roman',weight="bold")
fz2 = font.Font(size=15,family='Times New Roman',weight="bold")

p = PanedWindow(fp, orient=HORIZONTAL)

F1 = Frame(fp, bg='gold', bd=5,relief = RAISED)
Label(F1,text='Machine Learning : Liste des Algorithmes',font=("Courier", 20,"bold")).pack(padx = 10, pady = 10)
F1.pack(padx =10, pady = 10)




Frame3 = Frame(fp,borderwidth=1,relief=GROOVE)
Label(Frame3,text="RDV dentiste à 10h",bg="white").pack(padx=80,pady=250)
#Button(Frame3,text="Effacer",fg='navy',command=Frame3.destroy)
Frame3.pack(side=LEFT)



Frame3.pack(fill=tk.BOTH, expand=True)


Frame4 = Frame(fp,borderwidth=1,relief=GROOVE)
Label(Frame4,text="RDV dentiste à minuit",bg="white").pack(padx=250,pady=250)
#Button(Frame3,text="Effacer",fg='navy',command=Frame3.destroy)
Frame4.pack(side=RIGHT)

Frame4.pack(fill=tk.BOTH, expand=True)


fp.title('Machine Learning') # Ajout d'un titre
fp.resizable(True, True) # autoriser le redimensionnement vertical et horizontal
fp.geometry("1072x800+80+50")#dimensionner et positionner la fnêtre

menubar = Menu(fp)

menufile = Menu(menubar,tearoff=0)


menufile.add_command(label="Open ",command=onOpen)
menufile.add_separator()

def onSave():
    print(filedialog.asksaveasfilename(initialdir = "/",title = "Save as",filetypes = (("Python files","*.py;*.pyw"),("All files","*.*"))))

menufile.add_command(label="Save",command=onSave)
menufile.add_separator()


menufile.add_command(label="Save as")
menufile.add_separator()


menufile.add_command(label="Quit", command=fp.destroy) 
menufile.add_separator()

menubar.add_cascade(label="File", menu=menufile)

menuedition = Menu(menubar,tearoff=0)

def alert():
    showinfo("alerte", "Thank You!")


menuedition.add_command(label="Cut")
menuedition.add_separator()

menuedition.add_command(label="Copy")
menuedition.add_separator()

menuedition.add_command(label="Past")
menuedition.add_separator()

menuedition.add_cascade(label="Edit")
menuedition.add_separator()

menubar.add_cascade(label="Edit", menu=menuedition)

menuhelp = Menu(menubar, tearoff=0)
menuhelp.add_command(label="About !", command=alert)
menubar.add_cascade(label="Help", menu=menuhelp)


fp.config(menu=menubar)

p.pack()
fp.mainloop()
# Out:
# E:/candidature master FS sfax.pdf
# No file exists

# %%
import tkinter.filedialog
import tkinter as tk
from tkinter import * 
import tkinter.font as font
from tkinter.filedialog import askopenfilename
import os


def onOpen():
    rep = filedialog.askopenfilenames(
    	parent=fp,
    	initialdir='/',
    	initialfile='tmp',
    	filetypes=[
    		("Python", "*.py"),
    		("Text", "*.txt"),
    		("All files", "*")])
    print(rep)
    try:
	    os.startfile(rep[0])
    except IndexError:
        print("No file selected")

fp =Tk()





p = PanedWindow(fp, orient=HORIZONTAL)


fp.title('Machine Learning') # Ajout d'un titre
fp.resizable(True, True) # autoriser le redimensionnement vertical et horizontal
fp.geometry("1072x800+80+50")#dimensionner et positionner la fnêtre

menubar = Menu(fp)
fp.config(menu=menubar)

menufile = Menu(menubar,tearoff=0)


menufile.add_command(label="Open ",command=onOpen)
menufile.add_separator()

def onSave():
    print(filedialog.asksaveasfilename(initialdir = "C:/",title = "Save as",filetypes = (("Python files","*.py;*.pyw"),("All files","*.*"))))

menufile.add_command(label="Save",command=onSave)
menufile.add_separator()


menufile.add_command(label="Save as")
menufile.add_separator()


menufile.add_command(label="Quit", command=fp.destroy) 
menufile.add_separator()

menubar.add_cascade(label="File", menu=menufile)

menuedition = Menu(menubar,tearoff=0)

def alert():
    showinfo("alerte", "Thank You!")


menuedition.add_command(label="Cut")
menuedition.add_separator()

menuedition.add_command(label="Copy")
menuedition.add_separator()

menuedition.add_command(label="Past")
menuedition.add_separator()

menuedition.add_cascade(label="Edit")
menuedition.add_separator()

menubar.add_cascade(label="Edit", menu=menuedition)

menuhelp = Menu(menubar, tearoff=0)
menuhelp.add_command(label="About !", command=alert)
menubar.add_cascade(label="Help", menu=menuhelp)


#fp.config(menu=menubar)

p.pack()
fp.mainloop()

# %%
import tkinter.filedialog
import tkinter as tk
from tkinter import * 
import tkinter.font as font
from tkinter.filedialog import askopenfilename
import os

def onOpen():
    #print(filedialog.askopenfilename(initialdir = "/",title = "Open file",filetypes = (("Python files","*.py;*.pyw"),("All files","*.*")))) 
    rep = filedialog.askopenfilenames(
    	parent=fp,
    	initialdir='/',
    	initialfile='tmp',
    	filetypes=[
    		("Python", ["*.py","*.ipynb"]),
      		("Pdf", "*.pdf"),
    		("Text", "*.txt"),
    		("All files", "*")])
    print(rep)
    try:
	    os.startfile(rep[0])
    except IndexError:
        print("No file selected")



fp =Tk()


fz1 = font.Font(size=40,family='Times New Roman',weight="bold")
fz2 = font.Font(size=15,family='Times New Roman',weight="bold")

p = PanedWindow(fp, orient=HORIZONTAL)

F1 = Frame(fp, bg='gold', bd=5,relief = RAISED)
Label(F1,text='Machine Learning : Liste des Algorithmes',font=("Courier", 20,"bold")).pack(padx = 10, pady = 10)
F1.pack(padx =10, pady = 10)




Frame3 = Frame(fp,borderwidth=1,relief=GROOVE)
Label(Frame3,text="RDV dentiste à 10h",bg="white").pack(padx=80,pady=250)
#Button(Frame3,text="Effacer",fg='navy',command=Frame3.destroy)
Frame3.pack(side=LEFT)



Frame3.pack(fill=tk.BOTH, expand=True)


Frame4 = Frame(fp,borderwidth=1,relief=GROOVE)
Label(Frame4,text="RDV dentiste à minuit",bg="white").pack(padx=250,pady=250)
#Button(Frame3,text="Effacer",fg='navy',command=Frame3.destroy)
Frame4.pack(side=RIGHT)

Frame4.pack(fill=tk.BOTH, expand=True)


fp.title('Machine Learning') # Ajout d'un titre
fp.resizable(True, True) # autoriser le redimensionnement vertical et horizontal
fp.geometry("1072x800+80+50")#dimensionner et positionner la fnêtre

menubar = Menu(fp)

menufile = Menu(menubar,tearoff=0)


menufile.add_command(label="Open ",command=onOpen)
menufile.add_separator()

def onSave():
    print(filedialog.asksaveasfilename(initialdir = "/",title = "Save as",filetypes = (("Python files","*.py;*.pyw"),("All files","*.*"))))

menufile.add_command(label="Save",command=onSave)
menufile.add_separator()


menufile.add_command(label="Save as")
menufile.add_separator()


menufile.add_command(label="Quit", command=fp.destroy) 
menufile.add_separator()

menubar.add_cascade(label="File", menu=menufile)

menuedition = Menu(menubar,tearoff=0)

def alert():
    showinfo("alerte", "Thank You!")


menuedition.add_command(label="Cut")
menuedition.add_separator()

menuedition.add_command(label="Copy")
menuedition.add_separator()

menuedition.add_command(label="Past")
menuedition.add_separator()

menuedition.add_cascade(label="Edit")
menuedition.add_separator()

menubar.add_cascade(label="Edit", menu=menuedition)

menuhelp = Menu(menubar, tearoff=0)
menuhelp.add_command(label="About !", command=alert)
menubar.add_cascade(label="Help", menu=menuhelp)


fp.config(menu=menubar)

p.pack()
fp.mainloop()
# Out:
# ('E:/session_mai2021_isigk.pdf',)

# %%
import tkinter.filedialog
import tkinter as tk
from tkinter import * 
import tkinter.font as font
from tkinter.filedialog import askopenfilename
import os
import webbrowser

def onOpen():
    #print(filedialog.askopenfilename(initialdir = "/",title = "Open file",filetypes = (("Python files","*.py;*.pyw"),("All files","*.*")))) 
    rep = filedialog.askopenfilenames(
    	parent=fp,
    	initialdir='/',
    	initialfile='tmp',
    	filetypes=[
    		("Python", ["*.py","*.ipynb"]),
      		("Pdf", "*.pdf"),
    		("Text", "*.txt"),
    		("All files", "*")])
    print(rep)
    try:
	    os.startfile(rep[0])
    except IndexError:
        print("No file selected")


def openAlgo1():
    #print(filedialog.askopenfilename(initialdir = "/",title = "Open file",filetypes = (("Python files","*.py;*.pyw"),("All files","*.*")))) 
    webbrowser.open_new(r"file://C:\Users\MSI\TravailPython\Travail personnel\Pour Mme Lamia\Covid-19 Data Analysis and Predcitions\Covid-19 Data Analysis and Predcitions.ipynb")
   
        

fp =Tk()


fz1 = font.Font(size=40,family='Times New Roman',weight="bold")
fz2 = font.Font(size=15,family='Times New Roman',weight="bold")

p = PanedWindow(fp, orient=HORIZONTAL)

F1 = Frame(fp, bg='gold', bd=5,relief = RAISED)
Label(F1,text='Machine Learning : Liste des Algorithmes',font=("Courier", 20,"bold")).pack(padx = 10, pady = 10)
F1.pack(padx =10, pady = 10)




Frame3 = Frame(fp,borderwidth=1,relief=GROOVE)
Label(Frame3).pack(fill=tk.BOTH)
Algo1=Button(Frame3,text="Covid-19 Data Analysis and Predcitions",fg='navy',command=openAlgo1).pack(side=TOP,fill=tk.BOTH)
#Algo1.pack(side = TOP)
Frame3.pack(side=LEFT)
Frame3.pack(fill=tk.BOTH, expand=True)

Frame4 = Frame(fp,borderwidth=1,relief=GROOVE)
Label(Frame4,text="Projet : Réalisé par Tahar ALIMI",bg="white",font=("Courier", 20,"bold")).pack(fill=tk.BOTH)
Frame4.pack(side=RIGHT)
Frame4.pack(fill=tk.BOTH, expand=True)


#lbl = tk.Label(fp, text=r"Covid-19 Data Analysis and Predcitions", fg="blue", cursor="hand2")
link1 = Label(Frame4, text="Google Hyperlink", fg="blue", cursor="hand2")
link1.pack(side=TOP)
link1.bind("<Button-1>", lambda e: webbrowser.open_new(r"file://C:\Users\MSI\TravailPython\Travail personnel\Pour Mme Lamia\Covid-19 Data Analysis and Predcitions\Covid-19 Data Analysis and Predcitions.ipynb"))


fp.title('Machine Learning') # Ajout d'un titre
fp.resizable(True, True) # autoriser le redimensionnement vertical et horizontal
fp.geometry("1072x800+80+50")#dimensionner et positionner la fnêtre

menubar = Menu(fp)

menufile = Menu(menubar,tearoff=0)


menufile.add_command(label="Open ",command=onOpen)
menufile.add_separator()

def onSave():
    print(filedialog.asksaveasfilename(initialdir = "/",title = "Save as",filetypes = (("Python files","*.py;*.pyw"),("All files","*.*"))))

menufile.add_command(label="Save",command=onSave)
menufile.add_separator()


menufile.add_command(label="Save as")
menufile.add_separator()


menufile.add_command(label="Quit", command=fp.destroy) 
menufile.add_separator()

menubar.add_cascade(label="File", menu=menufile)

menuedition = Menu(menubar,tearoff=0)

def alert():
    showinfo("alerte", "Thank You!")


menuedition.add_command(label="Cut")
menuedition.add_separator()

menuedition.add_command(label="Copy")
menuedition.add_separator()

menuedition.add_command(label="Past")
menuedition.add_separator()

menuedition.add_cascade(label="Edit")
menuedition.add_separator()

menubar.add_cascade(label="Edit", menu=menuedition)

menuhelp = Menu(menubar, tearoff=0)
menuhelp.add_command(label="About !", command=alert)
menubar.add_cascade(label="Help", menu=menuhelp)


fp.config(menu=menubar)

p.pack()
fp.mainloop()

# %%
import tkinter.filedialog
import tkinter as tk
from tkinter import * 
import tkinter.font as font
from tkinter.filedialog import askopenfilename
import os
import webbrowser

def onOpen():
    #print(filedialog.askopenfilename(initialdir = "/",title = "Open file",filetypes = (("Python files","*.py;*.pyw"),("All files","*.*")))) 
    rep = filedialog.askopenfilenames(
    	parent=fp,
    	initialdir='/',
    	initialfile='tmp',
    	filetypes=[
    		("Python", ["*.py","*.ipynb"]),
      		("Pdf", "*.pdf"),
    		("Text", "*.txt"),
    		("All files", "*")])
    print(rep)
    try:
	    os.startfile(rep[0])
    except IndexError:
        print("No file selected")


def openAlgo1():
    #print(filedialog.askopenfilename(initialdir = "/",title = "Open file",filetypes = (("Python files","*.py;*.pyw"),("All files","*.*")))) 
    webbrowser.open_new(r"file://C:\Users\MSI\TravailPython\Travail personnel\Pour Mme Lamia\Covid-19 Data Analysis and Predcitions\Covid-19 Data Analysis and Predcitions.ipynb")
   
        

fp =Tk()


fz1 = font.Font(size=40,family='Times New Roman',weight="bold")
fz2 = font.Font(size=15,family='Times New Roman',weight="bold")

p = PanedWindow(fp, orient=HORIZONTAL)

F1 = Frame(fp, bg='gold', bd=5,relief = RAISED)
Label(F1,text='Machine Learning : Liste des Algorithmes',font=("Courier", 20,"bold")).pack(padx = 10, pady = 10)
F1.pack(padx =10, pady = 10)




Frame3 = Frame(fp,borderwidth=1,relief=GROOVE)
Label(Frame3).pack(fill=tk.BOTH)
Frame3.pack(side=LEFT)
Frame3.pack(fill=tk.BOTH, expand=True)

Frame4 = Frame(fp,borderwidth=1,relief=GROOVE)
Label(Frame4,text="Projet : Réalisé par Tahar ALIMI",bg="white",font=("Courier", 20,"bold")).pack(fill=tk.BOTH)
Frame4.pack(side=RIGHT)
Frame4.pack(fill=tk.BOTH, expand=True)

OptionList = [
"Nous avons donc 150 observations de 4 valeurs !!",
"Observer avec Seaborn",
"Apprentissage supervisé",
"Apprentissage non supervisé"
] 


variable = tk.StringVar(fp)
variable.set(OptionList[0])

labelTest = tk.Label(text="", font=('Helvetica', 12), fg='red')
labelTest.pack(side="top")

def callback(*args):
    labelTest.configure(text="{}".format(variable.get()))

variable.trace("w", callback)


opt = tk.OptionMenu(fp, variable, *OptionList)
opt.config(width=90, font=('Helvetica', 12))
opt.pack()



#Algo1=Button(Frame3,text="Covid-19 Data Analysis and Predcitions",fg='navy',command = lambda listbox=listbox: listbox.delete(ANCHOR)).pack(side=TOP,fill=tk.BOTH)
#Algo1.pack()



fp.title('Machine Learning') # Ajout d'un titre
fp.resizable(True, True) # autoriser le redimensionnement vertical et horizontal
fp.geometry("1072x800+80+50")#dimensionner et positionner la fnêtre

menubar = Menu(fp)

menufile = Menu(menubar,tearoff=0)


menufile.add_command(label="Open ",command=onOpen)
menufile.add_separator()

def onSave():
    print(filedialog.asksaveasfilename(initialdir = "/",title = "Save as",filetypes = (("Python files","*.py;*.pyw"),("All files","*.*"))))

menufile.add_command(label="Save",command=onSave)
menufile.add_separator()


menufile.add_command(label="Save as")
menufile.add_separator()


menufile.add_command(label="Quit", command=fp.destroy) 
menufile.add_separator()

menubar.add_cascade(label="File", menu=menufile)

menuedition = Menu(menubar,tearoff=0)

def alert():
    showinfo("alerte", "Thank You!")


menuedition.add_command(label="Cut")
menuedition.add_separator()

menuedition.add_command(label="Copy")
menuedition.add_separator()

menuedition.add_command(label="Past")
menuedition.add_separator()

menuedition.add_cascade(label="Edit")
menuedition.add_separator()

menubar.add_cascade(label="Edit", menu=menuedition)

menuhelp = Menu(menubar, tearoff=0)
menuhelp.add_command(label="About !", command=alert)
menubar.add_cascade(label="Help", menu=menuhelp)


fp.config(menu=menubar)

p.pack()
fp.mainloop()

# %%
import tkinter.filedialog
import tkinter as tk
from tkinter import ttk
from tkinter import * 
import tkinter.font as font
from tkinter.filedialog import askopenfilename
import os
import webbrowser
from tkinter.messagebox import showinfo

def funcIris(event):
    if objListDeroul.get() == "Apprentissage supervisé" :
        webbrowser.open_new(r"file://C:\Users\MSI\TravailPython\Travail personnel\Pour Mme Lamia\IRIS\IRIS App Sup.pdf")
    elif objListDeroul.get() == "Apprentissage non supervisé" :
        webbrowser.open_new(r"file://C:\Users\MSI\TravailPython\Travail personnel\Pour Mme Lamia\IRIS\IRIS App Non Sup.pdf")
    else :
        showinfo("Info","Votre choix! !!")
    

def onOpen():
    #print(filedialog.askopenfilename(initialdir = "/",title = "Open file",filetypes = (("Python files","*.py;*.pyw"),("All files","*.*")))) 
    rep = filedialog.askopenfilenames(
    	parent=fp,
    	initialdir='/',
    	initialfile='tmp',
    	filetypes=[
    		("Python", ["*.py","*.ipynb"]),
      		("Pdf", "*.pdf"),
    		("Text", "*.txt"),
    		("All files", "*")])
    print(rep)
    try:
	    os.startfile(rep[0])
    except IndexError:
        print("No file selected")


def openAlgo1():

    webbrowser.open_new(r"file://C:\Users\MSI\TravailPython\Travail personnel\Pour Mme Lamia\Covid-19 Data Analysis and Predcitions\Covid-19 Data Analysis and Predcitions.ipynb")
def openMobile():
    webbrowser.open_new(r"file://C:\Users\MSI\TravailPython\Travail personnel\Pour Mme Lamia\Regression_Lineaire_Mobile_Price_Predicion\Mobile_Price_Prediction.pdf")
   
           
        

fp =Tk()


fz1 = font.Font(size=40,family='Times New Roman',weight="bold")
fz2 = font.Font(size=15,family='Times New Roman',weight="bold")

p = PanedWindow(fp, orient=HORIZONTAL)

F1 = Frame(fp, bg='gold', bd=5,relief = RAISED)
Label(F1,text='Machine Learning : Liste des Algorithmes',font=("Courier", 20,"bold")).pack(padx = 10, pady = 10)
F1.pack(padx =10, pady = 10)




Frame3 = Frame(fp,borderwidth=1,relief=GROOVE)
Label(Frame3).pack(fill=tk.BOTH)
Frame3.pack(side=LEFT)
Frame3.pack(fill=tk.BOTH, expand=True)

Frame4 = Frame(fp,borderwidth=1,relief=GROOVE)
Label(Frame4,text="Projet : Réalisé par Tahar ALIMI",bg="white",font=("Courier", 20,"bold")).pack(fill=tk.BOTH)
Frame4.pack(side=RIGHT)
Frame4.pack(fill=tk.BOTH, expand=True)

OptionList = [
"Votre choix !! -- Découvrir en Images !!",
"Apprentissage supervisé",
"Apprentissage non supervisé"
] 

Algo1=Button(Frame3,text="Mobile_Price_Prediction",borderwidth = 5,font=("Courier", 15,"bold"),fg='PaleVioletRed',bg="lightblue1",command = openMobile).pack(side=TOP,fill=tk.BOTH)

objListDeroul = tk.Label(Frame3,text = "IRIS ",borderwidth = 5,font=("Courier", 20,"bold")).pack(side=TOP)

objListDeroul = ttk.Combobox(Frame3, values=OptionList, width=16)


#objListDeroul.grid(column=0, row=1)
objListDeroul.current(0)
objListDeroul.bind("<<ComboboxSelected>>", funcIris)
objListDeroul.pack(fill=tk.BOTH)

fp.title('Machine Learning') # Ajout d'un titre
fp.resizable(True, True) # autoriser le redimensionnement vertical et horizontal
fp.geometry("1072x800+80+50")#dimensionner et positionner la fnêtre

menubar = Menu(fp)
menufile = Menu(menubar,tearoff=0)
menufile.add_command(label="Open ",command=onOpen)
menufile.add_separator()

def onSave():
    print(filedialog.asksaveasfilename(initialdir = "/",title = "Save as",filetypes = (("Python files","*.py;*.pyw"),("All files","*.*"))))

menufile.add_command(label="Save",command=onSave)
menufile.add_separator()


menufile.add_command(label="Save as")
menufile.add_separator()


menufile.add_command(label="Quit", command=fp.destroy) 
menufile.add_separator()

menubar.add_cascade(label="File", menu=menufile)

menuedition = Menu(menubar,tearoff=0)

def alert():
    showinfo("alerte", "Thank You!")


menuedition.add_command(label="Cut")
menuedition.add_separator()

menuedition.add_command(label="Copy")
menuedition.add_separator()

menuedition.add_command(label="Past")
menuedition.add_separator()

menuedition.add_cascade(label="Edit")
menuedition.add_separator()

menubar.add_cascade(label="Edit", menu=menuedition)

menuhelp = Menu(menubar, tearoff=0)
menuhelp.add_command(label="About !", command=alert)
menubar.add_cascade(label="Help", menu=menuhelp)


fp.config(menu=menubar)

p.pack()
fp.mainloop()

# %%
import tkinter.filedialog
import tkinter as tk
from tkinter import ttk
from tkinter import * 
import tkinter.font as font
from tkinter.filedialog import askopenfilename
import os
import webbrowser
from tkinter.messagebox import showinfo

def onSave():
    print(filedialog.asksaveasfilename(initialdir = "/",title = "Save as",filetypes = (("Python files","*.py;*.pyw"),("All files","*.*"))))

def onOpen():
    #print(filedialog.askopenfilename(initialdir = "/",title = "Open file",filetypes = (("Python files","*.py;*.pyw"),("All files","*.*")))) 
    rep = filedialog.askopenfilenames(
    	parent=fp,
    	initialdir='/',
    	initialfile='tmp',
    	filetypes=[
    		("Python", ["*.py","*.ipynb"]),
      		("Pdf", "*.pdf"),
    		("Text", "*.txt"),
    		("All files", "*")])
    print(rep)
    try:
	    os.startfile(rep[0])
    except IndexError:
        print("No file selected")


def openAlgo1():
    webbrowser.open_new(r"file://C:\Users\MSI\TravailPython\Travail personnel\Pour Mme Lamia\Regression_Lineaire_Mobile_Price_Predicion\Mobile_Price_Prediction.pdf")
    
def openAlgo2():
    webbrowser.open_new(r"file://C:\Users\MSI\TravailPython\Travail personnel\Pour Mme Lamia\Covid-19 Data Analysis and Predcitions\Covid-19 Data Analysis and Predcitions.pdf")
    
def openAlgo3():
    webbrowser.open_new(r"file://C:\Users\MSI\TravailPython\Travail personnel\Pour Mme Lamia\KNN-with-Panda-Module-abalone\KNN-abalone-with-panda-module.pdf")
    
def openAlgo4():
    webbrowser.open_new(r"file://C:\Users\MSI\TravailPython\Travail personnel\Pour Mme Lamia\Regression_Logistique\logistic Regression_infidelity_menage.pdf")
    
def openAlgo5():
    webbrowser.open_new(r"file://C:\Users\MSI\TravailPython\Travail personnel\Pour Mme Lamia\K-Means-Mall-Customers\k-Means_Mall_Customers_View_Clusters.pdf")
    
def openAlgo6()    :
    webbrowser.open_new(r"file://C:\Users\MSI\TravailPython\Travail personnel\Pour Mme Lamia\Vader sentiment analysis\vader_sentiment_analysis.pdf")
    
def openAlgo7()    :
    webbrowser.open_new(r"file://C:\Users\MSI\TravailPython\Travail personnel\Pour Mme Lamia\IRIS\IRIS.pdf")
    

fp =Tk()


fz1 = font.Font(size=40,family='Times New Roman',weight="bold")
fz2 = font.Font(size=15,family='Times New Roman',weight="bold")

p = PanedWindow(fp, orient=HORIZONTAL)

F1 = Frame(fp, bg='gold', bd=5,relief = RAISED)
Label(F1,text='Machine Learning : Liste des Algorithmes',font=("Courier", 20,"bold")).pack(padx = 10, pady = 10)
F1.pack(padx =10, pady = 10)




Frame3 = Frame(fp,borderwidth=1,relief=GROOVE)
Label(Frame3).pack(fill=tk.BOTH)
Frame3.pack(side=LEFT)
Frame3.pack(fill=tk.BOTH, expand=True)

Frame4 = Frame(fp,borderwidth=1,relief=GROOVE)
Label(Frame4,text="Projet : Réalisé par Tahar ALIMI",bg="white",font=("Courier", 20,"bold")).pack(fill=tk.BOTH)
Frame4.pack(side=RIGHT)
Frame4.pack(fill=tk.BOTH, expand=True)

Alg1=Button(Frame3,text="Mobile_Price_Prediction",borderwidth = 5,font=("Courier", 15,"bold"),
             fg='PaleVioletRed',bg="lightblue1",command = openAlgo1).pack(side=TOP,fill=tk.BOTH)

Alg2=Button(Frame3,text="Covid-19 Predcitions",borderwidth = 5,font=("Courier", 15,"bold"),fg='PaleVioletRed',bg="lightblue1",command = openAlgo2).pack(side=TOP,fill=tk.BOTH)

Alg3=Button(Frame3,text="KNN-abalone : Panda-module",borderwidth = 5,font=("Courier", 15,"bold"),fg='PaleVioletRed',bg="lightblue1",command = openAlgo3).pack(side=TOP,fill=tk.BOTH)

Alg4=Button(Frame3,text="logistic Regression_infidelity_menage",borderwidth = 5,font=("Courier", 15,"bold"),fg='PaleVioletRed',bg="lightblue1",command = openAlgo4).pack(side=TOP,fill=tk.BOTH)

Alg5=Button(Frame3,text="k-Means_Mall_Customers_View_Clusters",borderwidth = 5,font=("Courier", 15,"bold"),fg='PaleVioletRed',bg="lightblue1",command = openAlgo5).pack(side=TOP,fill=tk.BOTH)

Alg6=Button(Frame3,text="Vader_sentiment_analysis",borderwidth = 5,font=("Courier", 15,"bold"),fg='PaleVioletRed',bg="lightblue1",command = openAlgo6).pack(side=TOP,fill=tk.BOTH)

Alg7=Button(Frame3,text="Iris",borderwidth = 5,font=("Courier", 15,"bold"),fg='PaleVioletRed',bg="lightblue1",command = openAlgo7).pack(side=TOP,fill=tk.BOTH)




fp.title('Machine Learning') # Ajout d'un titre
fp.resizable(True, True) # autoriser le redimensionnement vertical et horizontal
fp.geometry("1072x800+80+50")#dimensionner et positionner la fnêtre

menubar = Menu(fp)
menufile = Menu(menubar,tearoff=0)
menufile.add_command(label="Open ",command=onOpen)
menufile.add_separator()

menufile.add_command(label="Save",command=onSave)
menufile.add_separator()


menufile.add_command(label="Save as")
menufile.add_separator()


menufile.add_command(label="Quit", command=fp.destroy) 
menufile.add_separator()

menubar.add_cascade(label="File", menu=menufile)

menuedition = Menu(menubar,tearoff=0)

def alert():
    showinfo("alerte", "Thank You!")


menuedition.add_command(label="Cut")
menuedition.add_separator()

menuedition.add_command(label="Copy")
menuedition.add_separator()

menuedition.add_command(label="Past")
menuedition.add_separator()

menuedition.add_cascade(label="Edit")
menuedition.add_separator()

menubar.add_cascade(label="Edit", menu=menuedition)

menuhelp = Menu(menubar, tearoff=0)
menuhelp.add_command(label="About !", command=alert)
menubar.add_cascade(label="Help", menu=menuhelp)


fp.config(menu=menubar)

p.pack()
fp.mainloop()
